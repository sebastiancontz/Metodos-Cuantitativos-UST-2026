# %% [markdown]
# |<img src="https://drive.google.com/uc?id=1kjzJXxk2dJDr_oNKOqgGjBPbu4v-s0NW" width="100px" height="100">| <p> Métodos Cuantitativos</p> <p>Ingeniería en Control de Gestión</p> <p>Unidad I: Estadística y Probabilidades con Python</p> <p>Sesión 4: Estadística univariada y métodos gráficos</p>|
# |:--- |:---|

# %% [markdown]
# ## Ejercicio 1
# Carga las siguientes librerías con sus respectivos alias:
# - `Pandas`
# - `Numpy`
# - `Seaborn`
#
# Una vez cargadas las librerías, obten el dataset `anscombe` usando `seaborn` y almacenalo en la variable `data`.
#
# Ocupa el siguiente código de referencia:
# ```python
# variable = sns.load_dataset("nombre_dataset")
# ```

# %%
# @title 1 - Ingresa tu respuesta acá

# %% [markdown]
# ## Ejercicio 2
#
# Agrupa el dataframe por la variable `dataset`, y calcula en una sola operación:
# - `media`
# - `varianza`
# - `desviación estándar`
#
# Comenta y discute los resultados con tus compañeros:
# - ¿son distintos los valores obtenidos?,
# - ¿existe una gran varianza en los datos?
# - ¿se podría hacer afirmación a priori?
#
# Usa el siguiente código para guiarte:
# ```python
# data_agrupada = dataframe.groupby("nombre_variable").agg([np.mean, np.?, np.?])
# ```

# %%
# @title 2 - Ingresa tu respuesta acá

# %% [markdown]
# ## Ejercicio 3
#
# Ejecuta el siguiente código, comenta y discute los resultados con tus compañeros:
# - ¿Son consistente los resultados anteriormente observados con los gráficos?.

# %%
# @title 3 - Ingresa tu respuesta acá

import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 2, figsize=(10, 6))

for dataset, ax in zip(data["dataset"].unique(), axs.flatten()):
  sns.regplot(data=data[data["dataset"] == dataset], x="x", y="y", ci=None, line_kws={"color": "orange"}, ax=ax)
  ax.set_title(f"Dataset {dataset}")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ejercicio 4
#
# - Carga el dataset `tips` de `seaborn` en la variable `data`.
# - Usando la función `histplot` genera un histograma de la variable `tip`, y responde:
# - ¿tiene algún tipo de sesgo la variable?
# - ¿es común que los cliente den una alta propina?
#
# Usa el siguiente código para guiarte:
# ```python
# ax = sns.histplot(data=dataframe, x="variable")
# plt.show()
# ```

# %%
# @title 4 - Ingresa tu respuesta acá

# %% [markdown]
# ## Ejercicio 5
#
# Usando el mismo conjunto de datos y la misma variable (`tip`), genera un gráfico de caja usando la función `boxplot` y responde:
# - ¿Se observan *outliers* en el gráfico?
# - ¿Cuánto es la propina aproximada que deja el 75% de la gente? (obten el dato sólo por observación del gráfico)
#
# Usa el siguiente código para guiarte:
# ```python
# ax = sns.boxplot(data=dataframe, x="variable")
# plt.show()
# ```

# %%
# @title 5 - Ingresa tu respuesta acá

# %% [markdown]
# ## Ejercicio 6
#
# - Elimina los `outliers` de la variable `tip` utilizando la eliminación por IQR.
#
# Guíate del siguiente código y fórmula:
# ```python
# q1 = np.quantile(dataframe["variable"], 0.?)
# q3 = np.quantile(dataframe["variable"], 0.?)
#
# iqr = ?
# lower = ?
# upper = ?
#
# dataframe = dataframe[
#   (dataframe["variable"] > lower) &
#   (dataframe["variable"] < upper)
# ]
# ```
#
# Fórmulas:
#
# - IQR = $Q_{3} - Q_{1}$
# - Limite inferior = $Q_{1} - (1.5 * IQR)$
# - Limite superior = $Q_{3} + (1.5 * IQR)$

# %%
# @title 6 - Ingresa tu respuesta acá

# %% [markdown]
# ## Ejercicio 7
#
# Vuelve a ejecutar el gráfico de caja anteriormente generado y responde:
# - ¿se observa algún cambio respecto a la ejecución anterior?
# - ¿se eliminaron todos los outliers?
# - ¿si quedaron outliers, por qué crees que no se eliminaron? ¿se debe a algún error en el código o es por otro motivo?

# %%
# @title 7 - Ingresa tu respuesta acá

# %% [markdown]
# ## Ejercicio 8
#
# - Genera un gráfico de caja utilizando el atributo `size` como la variable x y la variable `tip` como la variable y.
# - Responde: ¿se observa alguna relación entre estas variables?

# %%
# @title 8 - Ingresa tu respuesta acá

# %% [markdown]
# ## Ejercicio 9
#
# Utilizando seaborn, carga el dataset `dowjones` y almacenalo en la variable `djones`, y realiza las siguientes actividades:
# - Genera un histograma usando `seaborn` para la variable `Price`.
# - Calcula la `media` y la `mediana`.
# - En base a lo observado en el gráfico y en los estadísticos obtenidos, responde:
#   - Si tuvieras que presentar un resumen de esta información, ¿Cuál estadístico usarías? ¿Por qué?

# %%
# @title 9 - Ingresa tu respuesta acá

# %% [markdown]
# ## Ejercicio 10
#
# Vuelve a cargar el dataset `tips` de seaborn y almacenalo en la variable `data` y realiza la siguiente tarea:
# - Genera un histograma de la variable `tip`
# - Genera una columna llamada `tip_log`, a la cual debes asignar el cálculo del logaritmo de la variable `tip`.
# - Genera un nuevo histograma usando la variable `tip_log`.
# - Responde:
#   - ¿Cambió la distribución de los datos?
#   - ¿Por qué crees que sucedió este efecto?
#   - ¿Usarías esta transformación como una herramienta válida?
#
# Tip:
# ```python
# import numpy as np
#
# # aplicar logaritmo a columna
# dataframe["nombre_columna_log"] = dataframe["nombre_columna"].apply(np.log)
# ```

# %%
# @title 10 - Ingresa tu respuesta acá
