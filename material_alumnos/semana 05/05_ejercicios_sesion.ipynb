# %% [markdown]
# |<img src="https://drive.google.com/uc?id=1kjzJXxk2dJDr_oNKOqgGjBPbu4v-s0NW" width="100px" height="100">| <p> Métodos Cuantitativos</p> <p>Ingeniería en Control de Gestión</p> <p>Unidad I: Estadística y Probabilidades con Python</p> <p>Sesión 5: Distribuciones de probabilidad</p>|
# |:--- |:---|

# %% [markdown]
# ## Integrantes
# 1. Integrante 1
# 2. Integrante 2
# 3. Integrante 3

# %% [markdown]
# ## Ejercicio 1
# - Carga la librería `random`
# - Escribe una función llamada `lanzamiento_moneda` que simule el lanzamiento de una moneda con las alternativas `cara` y `cruz`.
#
# Guíate del siguiente código:
# ```python
# import random
#
# alternativa = random.choice(["A", "B", "C"])
# ```

# %%
# @title 1 - Ingresa tu respuesta acá

# %% [markdown]
# ## Ejercicio 2
#
# - Crea una segunda función llamada `probabilidad_cara`, la cual:
#   - Debe tener como parámetro el `numero_lanzamientos`
#   - Debe retornar la probabilidad de obtener `cara` en el lanzamiento de la moneda utilizando la función `lanzamiento_moneda`.
#
# #### Tip:
# - Ocupa un `for ` para iterar los `numero_lanzamientos`.
# - Crea una variable que acumule los resultados que resulten en `cara`.

# %%
# @title 2 - Ingresa tu respuesta acá

# %% [markdown]
# ## Ejercicio 3
#
# Reporta los resultados obtenidos para los siguientes lanzamientos, y genera una conclusión de manera posterior planteando qué sucede al incrementar el número de lanzamientos.
# - 10 simulaciones
# - 100 simulaciones
# - 1.000 simulaciones
# - 10.000 simulaciones
# - 1.000.000 simulaciones

# %%
# @title 3 - Ingresa tu respuesta acá

simulaciones = [10, 100, 1_000, 10_000, 1_000_000]

# %% [markdown]
# ## Ejercicio 4
#
# - Escribe una función llamada `tirar_dado` que simule el lanzamiento de una dado.
# - Escribe una segunda función llamada `probabilidad_impar` que cumpla con lo siguiente:
#   - Debe tener como parámetro el `numero_lanzamientos`.
#   - Debe retornar la probabilidad de obtener un número `impar` en el lanzamiento del dado utilizando la función `tirar_dado`.
#
# #### Tip
# - Recuerda que el operador `módulo` nos permite obtener el resto de una división en python.
# - El método `randint(limite_inferior, limite_superior)` de la librería `random` nos permite obtener un `int` aleatorio.

# %%
# @title 4 - Ingresa tu respuesta acá

# %% [markdown]
# ## Ejercicio 5
#
# Reporta los resultados obtenidos para los siguientes lanzamientos, y genera una conclusión de manera posterior planteando qué sucede al incrementar el número de lanzamientos.
# - 10 simulaciones
# - 100 simulaciones
# - 1.000 simulaciones
# - 10.000 simulaciones
# - 1.000.000 simulaciones

# %%
# @title 5 - Ingresa tu respuesta acá

simulaciones = [10, 100, 1_000, 10_000, 1_000_000]

# %% [markdown]
# ## Ejercicio 6
#
# - Crea los siguientes conjuntos ocupando el tipo de dato `set` de python.
#   - $Dado_{1} = \{ n° primos\}$
#   - $Dado_{2} = \{ n° pares\}$
#   - Debes respetar las condiciones del dado, es decir, números de 1 a 6
#   - Los conjuntos deben ser almacenados en las variables `dado_1` y `dado_2`
#   - La generación de los números debe ser a través de un ciclo `for` y no deben ser escritos de manera manual.
# - A partir de los conjuntos, reporta lo siguiente:
#   - $Dado_{1} \cup Dado_{2}$
#   - $Dado_{1} \cap Dado_{2}$
#   - $Dado_{1} - Dado_{2}$
#   - $Dado_{2} - Dado_{1}$
#   - $Dado_{2} \Delta Dado_{1}$
# - Ocupa la siguiente función para determinar si un número es primo:
# ```python
# def es_primo(numero):
#     if numero <= 1:
#         return False
#     for i in range(2, int(numero**0.5) + 1):
#         if numero % i == 0:
#             return False
#     return True
# ```
#
# Tip:
#
# Compresión de conjunto para crear dados:
# ```python
# dado_primos = {num for num in range(1,?) if funcion(num)}
#
# dado_pares = {num for num in range(1,?) if num ? 2 == ?}
# ```

# %%
# @title 6 - Ingresa tu respuesta acá

# %% [markdown]
# ## Ejercicio 7
#
# - Crea un tercer conjunto:
#   - $Dado_{3} = \{ n° impares\}$
# - A partir de los conjuntos, reporta lo siguiente:
#   - $Dado_{1}^c$

# %%
# @title 7 - Ingresa tu respuesta acá
