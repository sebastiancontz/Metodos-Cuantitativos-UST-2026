# %% [markdown]
# |<img src="https://drive.google.com/uc?id=1kjzJXxk2dJDr_oNKOqgGjBPbu4v-s0NW" width="100px" height="100">| <p> Métodos Cuantitativos</p> <p>Ingeniería en Control de Gestión</p> <p>Unidad I: Estadística y Probabilidades con Python</p> <p>Sesión 3: Introducción a la librería Pandas</p>|
# |:--- |:---|

# %% [markdown]
# ## Ejercicio 0
#
# - Ejecute la celda inferior para cargar los datos.

# %%
import random

# crear productos y categorías
productos = ['Camisa', 'Pantalón', 'Zapatos', 'Sombrero', 'Bolso', 'Bufanda', 'Gorro', 'Chaqueta', 'Vestido', 'Corbata', 'Calcetines', 'Guantes']
categorias = ['Ropa', 'Calzado', 'Accesorios']

# establecer una semilla
random.seed(0)

# crear un diccionario de datos de ejemplo
data = {
    'ID_Producto': [random.randint(100, 199) for _ in range(15)],
    'Nombre_Producto': [random.choice(productos) for _ in range(15)],
    'Categoria': [random.choice(categorias) for _ in range(15)],
    'Stock': [random.randint(0, 100) for _ in range(15)],
    'Precio_Unitario': [random.uniform(10000, 50000) for _ in range(15)],
    'Bodega': [random.randint(1, 5) for _ in range(15)]
}

# %% [markdown]
# ## Ejercicio 1
#
# - Importe la librería `Pandas` usando su respectivo alias.
# - Cree un DataFrame de Pandas llamado `df_tarea` usando la información cargada en la variable `data`.
# - Retorne los primeros `5` registros del DataFrame.
#
# Recuerde que para cargar un diccionario como DataFrame debe usar la siguiente sentencia:
# ```python
# diccionario = {
#   "nombre": ["Juan", "Gonzalo", "Francisco"],
#   "apellido": ["Castro", "Opazo", "Peréz"]
# }
# dataframe = pd.DataFrame(diccionario)
# ```

# %%
# @title 1 - Escriba su código acá

# %% [markdown]
# ## Ejercicio 2
#
# - Obtenga las estadísticas del dataframe y reporte:
#   - La media de la columna `Precio_Unitario`
#   - El mínimo y máximo del `Stock`
#
# Basta con:
# ```python
# print("La media de la columna X es n")
# print("El mínimo de stock es m")
# print("El máximo de stock es m")
# ```

# %%
# @title 2 - Escriba su código acá

# %% [markdown]
# ## Ejercicio 3
#
# - Reporte cuántos datos nulos existen el DataFrame.
# - Recuerde utilizar el método `sum` para obtener el resumen de los datos nulos.

# %%
# @title 3 - Escriba su código acá

# %% [markdown]
# ## Ejercicio 4
#
# - Reporte los `dtypes` del DataFrame.
# - Transforme las columnas que tengan dtype `float64` a `int`.
# - Una vez realizada la transformación, vuelva a reportar los `dtypes` y valide que la transformación fue correcta.

# %%
# @title 4 - Escriba su código acá

# %% [markdown]
# ## Ejercicio 5
#
# - Cree la columna `valorizacion_stock`, la cual debe ser producto de: `Stock` * `Precio_Unitario`.
# - Retorne una muestra de `10` elementos del DataFrame utilizando el método `sample`.
#
# Guíese del siguiente código
# ```python
# dataframe.sample(n_elementos)
# ```

# %%
# @title 5 - Escriba su código acá

# %% [markdown]
# ## Ejercicio 6
#
# - Reporte la suma acumulativa de la columna `valorizacion_stock`.

# %%
# @title 6 - Escriba su código acá

# %% [markdown]
# ## Ejercicio 7
#
# - Retorne los `Nombre_Producto` y `Stock` que pertenezcan a la categoría `Ropa` y `Calzado`.
#
# **Tips:**
# - Recuerde que los métodos `isin` y `query` pueden resultar útiles para realizar el filtrado.
# - Para traer múltiples columnas con una máscara de filtrado, guíese del siguiente código:
# ```python
# dataframe[dataframe["columna_filtro"].isin(["categoria_1", "categoria_2"])][["columna_1", "columna_2"]]
# ```

# %%
# @title 7 - Escriba su código acá

# %% [markdown]
# ## Ejercicio 8
#
# - Elimine de forma permanente las columnas `Bodega` y `valorizacion_stock`.
# - Reporte los últimos elementos del DataFrame.

# %%
# @title 8 - Escriba su código acá

# %% [markdown]
# ## Ejercicio 9
# - Cree la función `calcular_iva`, la cual debe recibir como argumento el `monto` y debe retornar el `monto * 0.19`
# - Cree la columna `monto_iva`, aplicando la función anteriormente creada, usando la columna `Precio_Unitario` como argumento.
# - Muestre los primeros `3` registros del DataFrame.
#
# Guíese del siguiente código:
# ```python
# def calcular_iva(argumento_1):
#   ...
#   return ...
#
# dataframe["nombre_columna"] = dataframe["nombre_columna_2"].apply(lambda x: calcular_iva(x))
# ```

# %%
# @title 9 - Escriba su código acá
