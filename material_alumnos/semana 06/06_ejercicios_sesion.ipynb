# %% [markdown]
# |<img src="https://drive.google.com/uc?id=1kjzJXxk2dJDr_oNKOqgGjBPbu4v-s0NW" width="100px" height="100">| <p> Métodos Cuantitativos</p> <p>Ingeniería en Control de Gestión</p> <p>Unidad I: Estadística y Probabilidades con Python</p> <p>Sesión 6: Distribuciones continuas</p>|
# |:--- |:---|

# %% [markdown]
# ## Integrantes:
# 1. Integrante 1
# 2. Integrante 2
# 3. Integrante 3

# %% [markdown]
# ## Ejercicio 1
# - Carga las librerías `numpy` y el módulo `uniform` de `scipy.stats`.
# - Usando la función `rvs` genera una variable aleatoria de tipo `uniforme discreta`, con un tamaño muestral de `1000` datos.
# - El limite inferior debe ser `0` y la amplitud del intervalo debe ser `10`.
# - Almacena la VA en la variable `rv`.
# - Ocupa como `random_state` el valor `2024`.
#
# Guíate del siguiente código:
#
# ```python
# uniform.rvs(
#   loc=limite_inferior,
#   scale=amplitud_intervalo,
#   size=tamano_muestra
# )
# ```

# %%
# @title 1 - Ingresa tu respuesta acá
from scipy.stats import uniform
import numpy as np

limite_inferior =
amplitud_intervalo =
tamano_muestra =
random_state =

rv = uniform.rvs(
  loc=limite_inferior,
  scale=amplitud_intervalo,
  size=tamano_muestra,
  random_state=random_state
)

# %%
# una vez finalizado la generación de rv, ejecuta el siguiente código
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(rv, discrete=True, stat="probability")
plt.show()

# %% [markdown]
# ## Ejercicio 2
#
# - Según el gráfico anterior, ¿se observa que la distribución sea realmente uniforme?
# - Calcula la $\mathbf{E}$ de la distribución, utilizando `uniform.mean`
# - ¿La media de la VA es igual a la $\mathbf{E}$ de la distribución con los parámetros ingresados?
# - Si existe una diferencia entre estos dos valores, ¿guardan alguna relación con el gráfico observado?
#
# Tip para obtener $\mathbf{E}$:
# ```python
# uniform.mean(limite_inferior, amplitud_intervalo)
# ```

# %%
# @title 2 - Ingresa tu respuesta acá

# %% [markdown]
# ## Ejercicio 3
#
# - Para este ejercicio, debes ocupar el módulo `binom` de `scipy.stats`.
# - Genera un experimento `binomial` con `10` ensayos, donde la probabilidad de éxito de cada ensayo es `0.5`.
# - Calcula la función de masa de probabilidad (PMF) para cada posible valor de éxito (0 a 10).
# - Almacena los resultados de la función `pmf` en la variable `exitos_pmf`.
# - Reporta los resultados, imprimiendo el número de éxitos y la probabilidad asociada.
#
# Guíate del siguiente código:
# ```python
# exitos = list(range(0, ?))
# ```
#
# Recuerda los argumentos de la función `pmf`:
# - `pmf(k, n, p)`
#   - `k`: es el número de éxitos.
#   - `n`: es el número total de ensayos.
#   - `p`: es la probabilidad de éxito en cada ensayo.

# %%
# @title 3 - Ingresa tu respuesta acá

# %% [markdown]
# ## Ejercicio 4
#
# - Siguiendo con el mismo experimento `binomial` del ejercicio anterior, calcula la función de distribución acumulativa (CDF) para los mismos valores de éxito (0 a 10).
# - Almacena los resultados de la función `cdf` en la variable `exitos_cdf`.
# - Reporta los resultados, imprimiendo el número de éxitos y la probabilidad acumulada asociada.

# %%
# @title 4 - Ingresa tu respuesta acá

# %% [markdown]
# ## Ejercicio 5
#
# En base a los ejercicios 4 y 5, responde:
# - ¿Qué indican los resultados reportados?
# - ¿Cuál es la principal diferencia entre ambas funciones?

# %%
# @title 5 - Ingresa tu respuesta acá

# %% [markdown]
# ## Ejercicio 6
#
# - Suponga que trabaja en el área de Inteligencia de Negocios de un callcenter. Luego de hacer un estudio, se obtiene que en promedio los operadores reciben `150` llamadas en cierto intervalo de tiempo.
# - Se necesita obtener la probabilidad que se reciban exactamente `190` llamadas en dicho intervalo de tiempo.
# - Reporte su resultado.
# - Utilice el módulo `poisson` de `scipy.stats`

# %%
# @title 6 - Ingresa tu respuesta acá

# %% [markdown]
# ## Ejercicio 7
#
# - ¿Cuál es la probabilidad de recibir `200` llamadas o menos?

# %%
# @title 7 - Ingresa tu respuesta acá

# %% [markdown]
# ## Ejercicio 8
#
# - ¿Cuál es la probabilidad de recibir más de `155` llamadas?

# %%
# @title 8 - Ingresa tu respuesta acá

# %% [markdown]
# ## Ejercicio 9
#
# - ¿Cuál es la probabilidad de recibir entre 120 y 150 llamadas?

# %%
# @title 9 - Ingresa tu respuesta acá

# %% [markdown]
# ## Ejercicio 10
#
# - Simule `1000` lanzamientos de `10` monedas trucadas con una probabilidad de éxito de `0.7` (obtener cara).
# - Utilice como `random_state=2000`.
# - Reporte:
#   - ¿Cuántas caras se obtuvieron?
#   - ¿Cuántas veces se obtuvo una racha de 10 éxitos?
#   - Si se utiliza una moneda normal, ¿cuántas rachas de victorias se obtiene? (use el mismo `random_state`)

# %%
# @title 10 - Ingresa tu respuesta acá
