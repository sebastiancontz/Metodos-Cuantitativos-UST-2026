# %% [markdown]
# |<p> Métodos Cuantitativos</p> <p>Ingeniería en Control de Gestión</p> <p>Unidad II: Regresión lineal y Test de hipótesis</p> <p>Solemne Unidad II</p>|
# |:---|

# %% [markdown]
# **Modalidad:** parejas
# **Puntaje oficial:** 60 puntos
# **Entrega:** notebook completo, ejecutado y con respuestas escritas en las celdas indicadas.
#
# Dataset: `https://raw.githubusercontent.com/mwaskom/seaborn-data/master/mpg.csv`

# %% [markdown]
# ## Identificacion
#
# - Nombre integrante 1:
# - RUT integrante 1:
#
# - Nombre integrante 2:
# - RUT integrante 2:

# %% [markdown]
# ## Instrucciones
#
# 1. Deben resolver los 5 ejercicios obligatorios. No hay ejercicios a eleccion en esta version.
# 2. Cada ejercicio es autocontenido: puede resolverse sin depender del codigo de ejercicios anteriores.
# 3. Cada respuesta debe incluir codigo, resultado e interpretacion escrita.
# 4. Use `statsmodels` para los modelos de regresion lineal y agregue intercepto con `sm.add_constant`.
# 5. Los ejercicios extra de test de hipotesis son opcionales: suman hasta 9 puntos brutos, pero el maximo cobrable es 5 puntos.

# %% [markdown]
# ## Pauta oficial: 60 puntos
#
# | Ejercicio | Foco | Puntaje |
# |---|---|---:|
# | 1 | Exploracion, correlacion y lectura critica | 12 |
# | 2 | Modelo simple, RMSE e interpretacion | 12 |
# | 3 | Modelo multiple y comparacion de metricas | 12 |
# | 4 | Supuestos del modelo | 12 |
# | 5 | Prediccion, rango y recomendacion | 12 |
# | **Total** |  | **60** |

# %% [markdown]
# <img src="data:image/png;base64,..." />

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tools.eval_measures import rmse

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/mpg.csv"
datos = pd.read_csv(url)

datos = datos.dropna(subset=[
    "mpg",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "cylinders",
    "origin",
]).copy()

display(datos.head())

# %%
# escriban aqui su codigo.

# %% [markdown]
# **Respuesta Ejercicio 1**
#
# Escriba aqui su interpretacion.

# %% [markdown]
# <img src="data:image/png;base64,..." />

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tools.eval_measures import rmse

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/mpg.csv"
datos = pd.read_csv(url)

datos = datos.dropna(subset=[
    "mpg",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "cylinders",
    "origin",
]).copy()

display(datos.head())

# %%
# escriban aqui su codigo.

# %% [markdown]
# **Respuesta Ejercicio 2**
#
# Escriba aqui la ecuacion, RMSE e interpretacion.

# %% [markdown]
# <img src="data:image/png;base64,..." />

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tools.eval_measures import rmse

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/mpg.csv"
datos = pd.read_csv(url)

datos = datos.dropna(subset=[
    "mpg",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "cylinders",
    "origin",
]).copy()

display(datos.head())

# %%
# Escriban aqui su codigo.

# %% [markdown]
# **Respuesta Ejercicio 3**
#
# Escriba aqui su comparacion de modelos.

# %% [markdown]
# <img src="data:image/png;base64,..." />

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tools.eval_measures import rmse

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/mpg.csv"
datos = pd.read_csv(url)

datos = datos.dropna(subset=[
    "mpg",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "cylinders",
    "origin",
]).copy()

display(datos.head())

# %%
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.stats.stattools import durbin_watson

# escriban aqui su codigo.

# %% [markdown]
# **Respuesta Ejercicio 4**
#
# - Linealidad:
# - Normalidad:
# - Homocedasticidad:
# - Independencia:
# - Conclusion general:

# %% [markdown]
# <img src="data:image/png;base64,..." />

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tools.eval_measures import rmse

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/mpg.csv"
datos = pd.read_csv(url)

datos = datos.dropna(subset=[
    "mpg",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "cylinders",
    "origin",
]).copy()

display(datos.head())

# %%
# escriban aqui su codigo.

# %% [markdown]
# **Respuesta Ejercicio 5**
#
# Escriba aqui prediccion, rango y clasificacion.

# %% [markdown]
# # Ejercicios extra de test de hipotesis
#
# Opcionales. Cada uno vale 3 puntos; maximo cobrable total: 5 puntos.

# %% [markdown]
# <img src="data:image/png;base64,..." />

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tools.eval_measures import rmse

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/mpg.csv"
datos = pd.read_csv(url)

datos = datos.dropna(subset=[
    "mpg",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "cylinders",
    "origin",
]).copy()

display(datos.head())

# %%
from scipy.stats import ttest_1samp

# escriban aqui su codigo.

# %% [markdown]
# **Respuesta Extra 1**
#
# Escriba aqui hipotesis, decision y conclusion.

# %% [markdown]
# <img src="data:image/png;base64,..." />

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tools.eval_measures import rmse

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/mpg.csv"
datos = pd.read_csv(url)

datos = datos.dropna(subset=[
    "mpg",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "cylinders",
    "origin",
]).copy()

display(datos.head())

# %%
from scipy.stats import ttest_ind

# Escriban aqui su codigo.

# %% [markdown]
# **Respuesta Extra 2**
#
# Escriba aqui hipotesis, decision, conclusion y limitacion.

# %% [markdown]
# <img src="data:image/png;base64,..." />

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tools.eval_measures import rmse

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/mpg.csv"
datos = pd.read_csv(url)

datos = datos.dropna(subset=[
    "mpg",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "cylinders",
    "origin",
]).copy()

display(datos.head())

# %%
from scipy.stats import chi2_contingency

# escriban aqui su codigo.

# %% [markdown]
# **Respuesta Extra 3**
#
# Escriba aqui hipotesis, decision, conclusion y comentario sobre causalidad.
